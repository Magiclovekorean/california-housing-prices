# %% [markdown]
# # Linear regression for predicting house prices of California
# Using (This datset)[https://www.kaggle.com/datasets/camnugent/california-housing-prices]

# %%
import pandas as pd
import numpy as np
import matplot.pyplot as plt
